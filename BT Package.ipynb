# %%
import bt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Download historical prices
bt_data = bt.get('fb, amzn, goog, nflx, aapl',
               start='2020-6-1', end='2020-12-1')
# Print the top five rows
print(bt_data.head())

# Define the strategy
bt_strategy = bt.Strategy('Trade_Weekly', 
                         [bt.algos.RunWeekly(),
                          bt.algos.SelectAll(),
                          bt.algos.WeighEqually(),
                          bt.algos.Rebalance()])
print(bt_strategy)

# Create a backtest
bt_test = bt.Backtest(bt_strategy, bt_data)
print(bt_test)
# Run the backtest
bt_res = bt.run(bt_test)

# Plot the test result
bt_res.plot(title="Backtest result")
plt.show()
# Out:
#                     fb         amzn         goog        nflx       aapl
# Date
# 2020-06-01  231.910004  2471.040039  1431.819946  425.920013  79.626671
# 2020-06-02  232.720001  2472.409912  1439.219971  427.309998  79.995293
# 2020-06-03  230.160004  2478.399902  1436.380005  421.970001  80.435677
# 2020-06-04  226.289993  2460.600098  1412.180054  414.329987  79.742950
# 2020-06-05  230.770004  2483.000000  1438.390015  419.600006  82.014114
# <Strategy Trade_Weekly>
# <bt.backtest.Backtest object at 0x00000212D89FF9C8>

# %%
bt_res.display()
# Out:
# Stat                 Trade_Weekly
# -------------------  --------------
# Start                2020-05-31
# End                  2020-12-01
# Risk-free rate       0.00%
#
# Total Return         31.08%
# Daily Sharpe         1.82
# Daily Sortino        3.03
# CAGR                 71.13%
# Max Drawdown         -16.71%
# Calmar Ratio         4.26
#
# MTD                  2.62%
# 3m                   -3.84%
# 6m                   31.08%
# YTD                  31.08%
# 1Y                   -
# 3Y (ann.)            -
# 5Y (ann.)            -
# 10Y (ann.)           -
# Since Incep. (ann.)  71.13%
#
# Daily Sharpe         1.82
# Daily Sortino        3.03
# Daily Mean (ann.)    58.00%
# Daily Vol (ann.)     31.94%
# Daily Skew           -0.32
# Daily Kurt           0.31
# Best Day             5.37%
# Worst Day            -5.24%
#
# Monthly Sharpe       1.94
# Monthly Sortino      4.34
# Monthly Mean (ann.)  50.13%
# Monthly Vol (ann.)   25.85%
# Monthly Skew         -0.72
# Monthly Kurt         0.45
# Best Month           13.10%
# Worst Month          -8.92%
#
# Yearly Sharpe        -
# Yearly Sortino       -
# Yearly Mean          -
# Yearly Vol           -
# Yearly Skew          -
# Yearly Kurt          -
# Best Year            -
# Worst Year           -
#
# Avg. Drawdown        -4.20%
# Avg. Drawdown Days   14.80
# Avg. Up Month        7.77%
# Avg. Down Month      -4.81%
# Win Year %           -
# Win 12m %            -

# %%
bt_res.plot_histogram()
# Out:
# C:\Users\m49834\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:316: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
bt_res.plot_security_weights()
